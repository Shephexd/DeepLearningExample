# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)
Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''

from __future__ import print_function

import tensorflow as tf
import time
# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 64
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)


# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
#Tensorflow GRAPH


# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}
with tf.device('/gpu:0'):
    # Construct model
    pred = conv_net(x, weights, biases, keep_prob)

    # Define loss and optimizer
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

    # Evaluate model
    correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

    # Initializing the variables
    init = tf.global_variables_initializer()

    
# Time checking
check_time = time.time()

# Launch the graph
with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
keep_prob: 1.}))
    
# GPU: 8.132946491241455
# CPU: 156.68687391281128
print(time.time() - check_time)
# Out:
# Iter 640, Minibatch Loss= 22366.484375, Training Accuracy= 0.26562
# Iter 1280, Minibatch Loss= 8615.752930, Training Accuracy= 0.54688
# Iter 1920, Minibatch Loss= 6791.555664, Training Accuracy= 0.73438
# Iter 2560, Minibatch Loss= 4732.390625, Training Accuracy= 0.70312
# Iter 3200, Minibatch Loss= 4512.561523, Training Accuracy= 0.75000
# Iter 3840, Minibatch Loss= 4023.637695, Training Accuracy= 0.71875
# Iter 4480, Minibatch Loss= 2968.786377, Training Accuracy= 0.82812
# Iter 5120, Minibatch Loss= 2088.272461, Training Accuracy= 0.84375
# Iter 5760, Minibatch Loss= 1417.447266, Training Accuracy= 0.87500
# Iter 6400, Minibatch Loss= 3174.902588, Training Accuracy= 0.82812
# Iter 7040, Minibatch Loss= 1727.255981, Training Accuracy= 0.87500
# Iter 7680, Minibatch Loss= 1498.107666, Training Accuracy= 0.89062
# Iter 8320, Minibatch Loss= 2080.961426, Training Accuracy= 0.85938
# Iter 8960, Minibatch Loss= 561.435791, Training Accuracy= 0.92188
# Iter 9600, Minibatch Loss= 1298.778687, Training Accuracy= 0.89062
# Iter 10240, Minibatch Loss= 2331.068604, Training Accuracy= 0.87500
# Iter 10880, Minibatch Loss= 1352.910645, Training Accuracy= 0.93750
# Iter 11520, Minibatch Loss= 2031.219727, Training Accuracy= 0.90625
# Iter 12160, Minibatch Loss= 716.258789, Training Accuracy= 0.87500
# Iter 12800, Minibatch Loss= 1252.884644, Training Accuracy= 0.90625
# Iter 13440, Minibatch Loss= 1717.113770, Training Accuracy= 0.84375
# Iter 14080, Minibatch Loss= 2109.551514, Training Accuracy= 0.85938
# Iter 14720, Minibatch Loss= 231.922394, Training Accuracy= 0.95312
# Iter 15360, Minibatch Loss= 1070.282593, Training Accuracy= 0.92188
# Iter 16000, Minibatch Loss= 578.917236, Training Accuracy= 0.92188
# Iter 16640, Minibatch Loss= 1389.476807, Training Accuracy= 0.93750
# Iter 17280, Minibatch Loss= 712.258179, Training Accuracy= 0.92188
# Iter 17920, Minibatch Loss= 1283.409546, Training Accuracy= 0.87500
# Iter 18560, Minibatch Loss= 1459.346924, Training Accuracy= 0.95312
# Iter 19200, Minibatch Loss= 1289.934204, Training Accuracy= 0.90625
# Iter 19840, Minibatch Loss= 1122.754517, Training Accuracy= 0.92188
# Iter 20480, Minibatch Loss= 862.583130, Training Accuracy= 0.93750
# Iter 21120, Minibatch Loss= 2382.082520, Training Accuracy= 0.81250
# Iter 21760, Minibatch Loss= 760.392944, Training Accuracy= 0.92188
# Iter 22400, Minibatch Loss= 1653.149048, Training Accuracy= 0.92188
# Iter 23040, Minibatch Loss= 926.001404, Training Accuracy= 0.92188
# Iter 23680, Minibatch Loss= 733.636719, Training Accuracy= 0.96875
# Iter 24320, Minibatch Loss= 774.582642, Training Accuracy= 0.92188
# Iter 24960, Minibatch Loss= 579.587097, Training Accuracy= 0.89062
# Iter 25600, Minibatch Loss= 858.443970, Training Accuracy= 0.93750
# Iter 26240, Minibatch Loss= 911.042786, Training Accuracy= 0.92188
# Iter 26880, Minibatch Loss= 527.992554, Training Accuracy= 0.85938
# Iter 27520, Minibatch Loss= 752.076477, Training Accuracy= 0.92188
# Iter 28160, Minibatch Loss= 1482.619873, Training Accuracy= 0.90625
# Iter 28800, Minibatch Loss= 307.531494, Training Accuracy= 0.96875
# Iter 29440, Minibatch Loss= 181.669586, Training Accuracy= 0.96875
# Iter 30080, Minibatch Loss= 1352.923950, Training Accuracy= 0.89062
# Iter 30720, Minibatch Loss= 95.626465, Training Accuracy= 0.98438
# Iter 31360, Minibatch Loss= 248.098495, Training Accuracy= 0.96875
# Iter 32000, Minibatch Loss= 751.297791, Training Accuracy= 0.93750
# Iter 32640, Minibatch Loss= 898.599976, Training Accuracy= 0.92188
# Iter 33280, Minibatch Loss= 373.713348, Training Accuracy= 0.95312
# Iter 33920, Minibatch Loss= 787.655029, Training Accuracy= 0.90625
# Iter 34560, Minibatch Loss= 325.035095, Training Accuracy= 0.96875
# Iter 35200, Minibatch Loss= 631.871643, Training Accuracy= 0.96875
# Iter 35840, Minibatch Loss= 136.299377, Training Accuracy= 0.98438
# Iter 36480, Minibatch Loss= 919.844971, Training Accuracy= 0.90625
# Iter 37120, Minibatch Loss= 459.466614, Training Accuracy= 0.92188
# Iter 37760, Minibatch Loss= 82.877319, Training Accuracy= 0.93750
# Iter 38400, Minibatch Loss= 234.563705, Training Accuracy= 0.96875
# Iter 39040, Minibatch Loss= 971.857178, Training Accuracy= 0.90625
# Iter 39680, Minibatch Loss= 416.739807, Training Accuracy= 0.96875
# Iter 40320, Minibatch Loss= 161.510315, Training Accuracy= 0.98438
# Iter 40960, Minibatch Loss= 1068.117554, Training Accuracy= 0.90625
# Iter 41600, Minibatch Loss= 328.163300, Training Accuracy= 0.92188
# Iter 42240, Minibatch Loss= 714.480957, Training Accuracy= 0.95312
# Iter 42880, Minibatch Loss= 423.286499, Training Accuracy= 0.96875
# Iter 43520, Minibatch Loss= 201.226257, Training Accuracy= 0.93750
# Iter 44160, Minibatch Loss= 78.052368, Training Accuracy= 0.98438
# Iter 44800, Minibatch Loss= 136.597260, Training Accuracy= 0.96875
# Iter 45440, Minibatch Loss= 363.471863, Training Accuracy= 0.93750
# Iter 46080, Minibatch Loss= 414.660339, Training Accuracy= 0.96875
# Iter 46720, Minibatch Loss= 321.790588, Training Accuracy= 0.93750
# Iter 47360, Minibatch Loss= 92.086365, Training Accuracy= 0.98438
# Iter 48000, Minibatch Loss= 292.072815, Training Accuracy= 0.96875
# Iter 48640, Minibatch Loss= 878.409302, Training Accuracy= 0.92188
# Iter 49280, Minibatch Loss= 861.065247, Training Accuracy= 0.93750
# Iter 49920, Minibatch Loss= 196.421951, Training Accuracy= 0.96875
# Iter 50560, Minibatch Loss= 51.456299, Training Accuracy= 0.96875
# Iter 51200, Minibatch Loss= 535.539856, Training Accuracy= 0.98438
# Iter 51840, Minibatch Loss= 445.637299, Training Accuracy= 0.90625
# Iter 52480, Minibatch Loss= 582.789429, Training Accuracy= 0.93750
# Iter 53120, Minibatch Loss= 295.994141, Training Accuracy= 0.95312
# Iter 53760, Minibatch Loss= 337.127045, Training Accuracy= 0.98438
# Iter 54400, Minibatch Loss= 251.518951, Training Accuracy= 0.95312
# Iter 55040, Minibatch Loss= 183.746353, Training Accuracy= 0.93750
# Iter 55680, Minibatch Loss= 372.125977, Training Accuracy= 0.95312
# Iter 56320, Minibatch Loss= 248.863495, Training Accuracy= 0.96875
# Iter 56960, Minibatch Loss= 566.186279, Training Accuracy= 0.92188
# Iter 57600, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 58240, Minibatch Loss= 418.559937, Training Accuracy= 0.95312
# Iter 58880, Minibatch Loss= 154.362183, Training Accuracy= 0.98438
# Iter 59520, Minibatch Loss= 134.820770, Training Accuracy= 0.98438
# Iter 60160, Minibatch Loss= 335.880249, Training Accuracy= 0.96875
# Iter 60800, Minibatch Loss= 427.290436, Training Accuracy= 0.95312
# Iter 61440, Minibatch Loss= 288.159760, Training Accuracy= 0.96875
# Iter 62080, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 62720, Minibatch Loss= 85.762604, Training Accuracy= 0.98438
# Iter 63360, Minibatch Loss= 657.431702, Training Accuracy= 0.93750
# Iter 64000, Minibatch Loss= 259.787354, Training Accuracy= 0.95312
# Iter 64640, Minibatch Loss= 319.034790, Training Accuracy= 0.96875
# Iter 65280, Minibatch Loss= 5.138962, Training Accuracy= 0.98438
# Iter 65920, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 66560, Minibatch Loss= 240.116043, Training Accuracy= 0.95312
# Iter 67200, Minibatch Loss= 222.716614, Training Accuracy= 0.95312
# Iter 67840, Minibatch Loss= 69.370117, Training Accuracy= 0.98438
# Iter 68480, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 69120, Minibatch Loss= 134.647949, Training Accuracy= 0.96875
# Iter 69760, Minibatch Loss= 124.640869, Training Accuracy= 0.96875
# Iter 70400, Minibatch Loss= 104.246803, Training Accuracy= 0.96875
# Iter 71040, Minibatch Loss= 84.378799, Training Accuracy= 0.98438
# Iter 71680, Minibatch Loss= 297.641052, Training Accuracy= 0.95312
# Iter 72320, Minibatch Loss= 16.890045, Training Accuracy= 0.96875
# Iter 72960, Minibatch Loss= 385.537079, Training Accuracy= 0.93750
# Iter 73600, Minibatch Loss= 142.568802, Training Accuracy= 0.98438
# Iter 74240, Minibatch Loss= 278.386047, Training Accuracy= 0.95312
# Iter 74880, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 75520, Minibatch Loss= 111.682037, Training Accuracy= 0.98438
# Iter 76160, Minibatch Loss= 380.043030, Training Accuracy= 0.90625
# Iter 76800, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 77440, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 78080, Minibatch Loss= 381.316223, Training Accuracy= 0.93750
# Iter 78720, Minibatch Loss= 148.748199, Training Accuracy= 0.96875
# Iter 79360, Minibatch Loss= 125.581802, Training Accuracy= 0.96875
# Iter 80000, Minibatch Loss= 150.558746, Training Accuracy= 0.98438
# Iter 80640, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 81280, Minibatch Loss= 834.368835, Training Accuracy= 0.90625
# Iter 81920, Minibatch Loss= 629.032288, Training Accuracy= 0.95312
# Iter 82560, Minibatch Loss= 496.279541, Training Accuracy= 0.93750
# Iter 83200, Minibatch Loss= 253.896149, Training Accuracy= 0.96875
# Iter 83840, Minibatch Loss= 372.542419, Training Accuracy= 0.95312
# Iter 84480, Minibatch Loss= 688.284119, Training Accuracy= 0.92188
# Iter 85120, Minibatch Loss= 87.581711, Training Accuracy= 0.95312
# Iter 85760, Minibatch Loss= 384.213165, Training Accuracy= 0.95312
# Iter 86400, Minibatch Loss= 323.321472, Training Accuracy= 0.92188
# Iter 87040, Minibatch Loss= 610.378357, Training Accuracy= 0.98438
# Iter 87680, Minibatch Loss= 254.698517, Training Accuracy= 0.96875
# Iter 88320, Minibatch Loss= 398.990417, Training Accuracy= 0.93750
# Iter 88960, Minibatch Loss= 128.929703, Training Accuracy= 0.95312
# Iter 89600, Minibatch Loss= 22.203186, Training Accuracy= 0.98438
# Iter 90240, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 90880, Minibatch Loss= 456.110229, Training Accuracy= 0.96875
# Iter 91520, Minibatch Loss= 12.723267, Training Accuracy= 0.98438
# Iter 92160, Minibatch Loss= 459.714905, Training Accuracy= 0.93750
# Iter 92800, Minibatch Loss= 122.485565, Training Accuracy= 0.96875
# Iter 93440, Minibatch Loss= 342.478027, Training Accuracy= 0.96875
# Iter 94080, Minibatch Loss= 645.812378, Training Accuracy= 0.92188
# Iter 94720, Minibatch Loss= 43.827515, Training Accuracy= 0.96875
# Iter 95360, Minibatch Loss= 172.655090, Training Accuracy= 0.96875
# Iter 96000, Minibatch Loss= 667.112549, Training Accuracy= 0.93750
# Iter 96640, Minibatch Loss= 385.071594, Training Accuracy= 0.96875
# Iter 97280, Minibatch Loss= 208.357742, Training Accuracy= 0.95312
# Iter 97920, Minibatch Loss= 370.310760, Training Accuracy= 0.98438
# Iter 98560, Minibatch Loss= 211.773239, Training Accuracy= 0.96875
# Iter 99200, Minibatch Loss= 214.270233, Training Accuracy= 0.98438
# Iter 99840, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Optimization Finished!
# Testing Accuracy: 0.980469
# 8.636760711669922

# %%
print(time.time())
# Out:
# 1496571723.8099527
